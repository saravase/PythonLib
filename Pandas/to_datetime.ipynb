# %%
import pandas as pd
dates=['2017-01-05','Jan 5,2017','01/05/2017','2017.01.05','2017/01/05','20170105']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05', '2017-01-05', '2017-01-05', '2017-01-05',
#                '2017-01-05', '2017-01-05'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates=['2017-01-05 2:30:00 PM','Jan 5,2017 14:30:00','01/05/2017','2017.01.05','2017/01/05','20170105']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05 14:30:00', '2017-01-05 14:30:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('5/1/2017',dayfirst=True)
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
dates=['2017-01-05 2:30:00 PM','Jan 5,2017 14:30:00','01/05/2017','2017.01.05','2017/01/05','20170105','abc']
pd.to_datetime(dates,errors='ignore')
# Out:
# array(['2017-01-05 2:30:00 PM', 'Jan 5,2017 14:30:00', '01/05/2017',
#        '2017.01.05', '2017/01/05', '20170105', 'abc'], dtype=object)

# %%
dates=['2017-01-05 2:30:00 PM','Jan 5,2017 14:30:00','01/05/2017','2017.01.05','2017/01/05','20170105','abc']
pd.to_datetime(dates,errors='coerce')
# Out:
# DatetimeIndex(['2017-01-05 14:30:00', '2017-01-05 14:30:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                                'NaT'],
#               dtype='datetime64[ns]', freq=None)

# %%
t=1523234265
dt=pd.to_datetime([t],unit='s')
dt
# Out:
# DatetimeIndex(['2018-04-09 00:37:45'], dtype='datetime64[ns]', freq=None)

# %%
dt.view('int64')
# Out:
# array([1523234265000000000], dtype=int64)
