# 2017-01-13  148.76  148.76  148.76  148.76  20743.23
# 2017-01-14  148.76  148.76  148.76  148.76  20743.23
# 2017-01-15  148.76  148.76  148.76  148.76  20743.23
# 2017-01-16  143.36  143.36  143.36  143.36  20123.23
# 2017-01-17  142.32  142.32  142.32  142.32  20432.12
# 2017-01-18  145.98  145.98  145.98  145.98  20487.23
# ...

# %%
df.asfreq('W',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2017-01-08  148.76  148.76  148.76  148.76  20743.23
# 2017-01-15  148.76  148.76  148.76  148.76  20743.23
# 2017-01-22  148.76  148.76  148.76  148.76  20743.23
# 2017-01-29  148.76  148.76  148.76  148.76  20743.23
# 2017-02-05  148.76  148.76  148.76  148.76  20743.23

# %%
df.asfreq('H',method='pad')
# Out:
#                        Open    High     Low   Close    Volume
# 2017-01-02 00:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 01:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 02:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 03:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 04:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 05:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 06:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 07:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 08:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 09:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 10:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 11:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 12:00:00  143.36  143.36  143.36  143.36  20123.23
# 2017-01-02 13:00:00  143.36  143.36  143.36  143.36  20123.23
# ...

# %%
 new_df=pd.date_range(start='1/1/2017',periods=72,freq="H")
new_df
# Out:
# DatetimeIndex(['2017-01-01 00:00:00', '2017-01-01 01:00:00',
#                '2017-01-01 02:00:00', '2017-01-01 03:00:00',
#                '2017-01-01 04:00:00', '2017-01-01 05:00:00',
#                '2017-01-01 06:00:00', '2017-01-01 07:00:00',
#                '2017-01-01 08:00:00', '2017-01-01 09:00:00',
#                '2017-01-01 10:00:00', '2017-01-01 11:00:00',
#                '2017-01-01 12:00:00', '2017-01-01 13:00:00',
#                '2017-01-01 14:00:00', '2017-01-01 15:00:00',
#                '2017-01-01 16:00:00', '2017-01-01 17:00:00',
#                '2017-01-01 18:00:00', '2017-01-01 19:00:00',
#                '2017-01-01 20:00:00', '2017-01-01 21:00:00',
#                '2017-01-01 22:00:00', '2017-01-01 23:00:00',
#                '2017-01-02 00:00:00', '2017-01-02 01:00:00',
#                '2017-01-02 02:00:00', '2017-01-02 03:00:00',
#                '2017-01-02 04:00:00', '2017-01-02 05:00:00',
# ...

# %%
import numpy as np
np.random.randint(1,10,len(new_df))
# Out:
# array([7, 2, 9, 5, 1, 9, 8, 6, 7, 3, 7, 3, 3, 6, 7, 1, 6, 8, 1, 8, 7, 8,
#        7, 8, 4, 9, 9, 9, 1, 3, 5, 8, 7, 9, 3, 1, 5, 6, 3, 1, 2, 9, 3, 4,
#        1, 2, 2, 1, 4, 9, 7, 2, 8, 6, 5, 2, 4, 1, 8, 2, 1, 6, 5, 8, 3, 3,
#        2, 1, 2, 6, 7, 9])

# %%
ts=pd.Series(np.random.randint(1,10,len(new_df)),index=new_df)
ts.head(10)
# Out:
# 2017-01-01 00:00:00    9
# 2017-01-01 01:00:00    4
# 2017-01-01 02:00:00    1
# 2017-01-01 03:00:00    2
# 2017-01-01 04:00:00    5
# 2017-01-01 05:00:00    3
# 2017-01-01 06:00:00    2
# 2017-01-01 07:00:00    2
# 2017-01-01 08:00:00    8
# 2017-01-01 09:00:00    5
# Freq: H, dtype: int32
